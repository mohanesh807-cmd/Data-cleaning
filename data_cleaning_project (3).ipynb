# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    "Name": ["Arun", "Bala", "Chitra", "Divya", "Arun"],
    "Math": [78, 90, 65, 88, 78],
    "Science": [85, None, 70, 92, 85],
    "English": [88, 76, 72, 95, 88],
    "Attendance": [90, 85, None, 98, 90]
}

df = pd.DataFrame(data)
df
# Out:
#      Name  Math  Science  English  Attendance
# 0    Arun    78     85.0       88        90.0
# 1    Bala    90      NaN       76        85.0
# 2  Chitra    65     70.0       72         NaN
# 3   Divya    88     92.0       95        98.0
# 4    Arun    78     85.0       88        90.0

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        5 non-null      str
#  1   Math        5 non-null      int64
#  2   Science     4 non-null      float64
#  3   English     5 non-null      int64
#  4   Attendance  4 non-null      float64
# dtypes: float64(2), int64(2), str(1)
# memory usage: 332.0 bytes
# Name          0
# Math          0
# Science       1
# English       0
# Attendance    1
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Name          0
# Math          0
# Science       1
# English       0
# Attendance    1
# dtype: int64

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      Name  Math  Science  English  Attendance
# 0    Arun    78     85.0       88        90.0
# 1    Bala    90      NaN       76        85.0
# 2  Chitra    65     70.0       72         NaN
# 3   Divya    88     92.0       95        98.0

# %%
sns.boxplot(data=df)
plt.title("Boxplot for Outlier Detection")
plt.show()

# %%
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
df.plot(x="Name", y="Math", kind="bar")
plt.title("Math Scores")
plt.show()

# %%
plt.hist(df["Math"])
plt.title("Distribution of Math Scores")
plt.show()

# %% [markdown]
# PROJECT INSIGHTS
#
# 1. Missing values were handled using mean method.
# 2. Duplicate records were removed.
# 3. Math and Science have positive correlation.
# 4. Attendance average is above 85%.
# 5. No major outliers detected.

# %%
df.to_csv("cleaned_student_data.csv", index=False)
